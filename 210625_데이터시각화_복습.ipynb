# %% [markdown]
# <a href="https://colab.research.google.com/github/JAEILJEON/JAEIL_DATA/blob/main/210625_%EB%8D%B0%EC%9D%B4%ED%84%B0%EC%8B%9C%EA%B0%81%ED%99%94_%EB%B3%B5%EC%8A%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 구글드라이브 연동

# %%
# 구글드라이브 연동
from google.colab import drive
drive.mount('/gdrive', force_remount=True)

# 구글 드라이브 파일 확인
# !ls '/gdrive/My Drive/temp/'

# 반복되는 드라이브 경로 변수화
drive_path = '/gdrive/My Drive/temp/'
# Out:
# Mounted at /gdrive
#  매수종목1.txt		   little-char.png	   seoul_map.html
#  매수종목2.txt		   ml_class.png		   sonar.csv
#  adult.data		   pca_1.png		   stock-data.csv
#  auto-mpg.csv		   pca_2.png		  'stock price.xlsx'
#  bmi_500.csv		   pca_3.png		  'stock valuation.xlsx'
#  citibike.csv		   Picture1.png		   test.db.db
#  매수종목.csv		   population_number.csv   test.txt
#  data_mine.csv		   ram_price.csv	   ThoraricSurgery.csv
#  data_population.csv	   ratings_small.txt	   titanic.xls
#  data_studentlist_en.csv   ratings_test.txt	   tmdb_5000_credits.csv
#  demo.docx		   ratings_train.txt	   tmdb_5000_movies.csv
#  diabetes.csv		   sample1.pdf		   Traffic_Accident_2017.csv
#  example.docx		   sample2.pdf		   train.csv
#  height_weight.txt	   sample.docx		   user_id_mean.csv
#  HelloWorld.xlsx	   sample_merge.pdf	   wine.csv
#  house_price.csv	   sample.xlsx		   주가데이터.xlsx
#  lenna.png		   score.csv		   남북한발전전력량.xlsx

# %% [markdown]
# # 데이터 시각화
#
# - 광범위하게 분산된 방대한 양의 자료를 한눈에 볼 수 있도록 도표나 차트 등으로 정리하는 것
# - 시각화를 통해 데이터의 특징을 쉽게 파악
# - 분석 결과를 상대방에게 효과적으로 전달 가능

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from pandas import DataFrame, Series #판다스 모듈 내의 DataFrame과 Series를 쓰겠다~
from numpy.random import randn       #넘파이 내부의 rand를 쓰겠다~ 세밀하게 이렇게 import해놓으면 불필요한 클래스나 모듈을 로드하지 않음. 필요한 것만 가져오기 가능.
# %matplotlib inline                  
# %config InlineBackend.figure_format = 'retina'
                                       #맷플로립 inline으로 연결해서 바로 출력되게 해주겠다. 이거랑 이 아랫줄은 늘 맷프로립과 함께한다고 생각하면 편함~

# %% [markdown]
# ## Matplotlib 기초

# %%
plt.plot( [2,4,6] ) #리스트로 2,4,6 넣어주겠다 #기본적으로 y값 넣어주면 됨. 기본적으로 x는 생략하고 y값은 꼭 넣어줘야함. 그래프에서 x,y하듯 y값은 꼭 넣자!
plt.show()
# x값은 내가 안줬기 때문에 그냥 프로그램이 알아서 처리했음.

# %%
#만약 어딘가 데이터가 이미 있었다면?
y = [2,4,6]

plt.plot(y) #이렇게 데이터값 넣어서 찍어내면 훨씬 편하지~
plt.show()

# %%
#만약 어딘가 데이터가 이미 있었다면?
x = [1,2,3]
y = [2,4,6]

plt.plot(x,y) #이렇게 데이터값 넣어서 찍어내면 훨씬 편하지~
plt.show() #plt.show() 안해도 그려지는 함. 근데 왜?

# %%
plt.plot(x ,y, ls = '--')
plt.show() #마지막에 plt하면 변수가 갖고 있는 값이 자동으로 출력되기 때문에 이걸 안넣어도 되긴 함.

# %% [markdown]
# Line style
#
# |Character| Description|
# |---|---|
# |‘ - ’| Solid line style|
# |‘ -- ’| Dashed line style|
# |‘ -. ’| Dash-dot lint style|
# |‘ : ’| Dotted line style|

# %%
x = [1,2,3]
y = [4,5,6]

plt.plot(x,y, ls = '-.') #ls가 linestyle 바꾸는 거임. 규칙 없어 그냥 만든 사람 마음임 이건 진짜 ㅋㅋ
plt.show()

# %% [markdown]
# Marker
#
# |Character| Description |Character| Description|
# |---|---|---|---|
# | ‘ . ’| Point marker |‘ 1 ’| Tri_down marker |
# |‘ o ’| Circle marker |‘ 2 ’| Tri_up marker |
# |‘ v ’| Triangle_down marker |‘ 3 ’| Tri_left marker |
# |‘ ^ ’| Triangle_up marker |‘ 4 ’| Tri_right marker |
# |‘ < ‘| Triangle_left marker |‘ * ‘| Star marker |
# |‘ > ‘| Triangle_right marker |‘ h ‘, ‘ H ’| Hexagon1,2 marker |
# |‘ s ‘| Square marker |‘ + ‘| Plus marker |
# |‘ p ‘| Pentagon marker |‘ D ‘| Diamond marker |
# |‘ | ‘| Vline marker |‘ _ ‘| Hline marker|

# %%
#데이터가 어디 있는지 찾고 싶어!
x = [1,2,3]
y = [4,5,6]

plt.plot(x, y, marker = 'o') #실제 값의 위치가 마커로 찍힘.
plt.show()

plt.plot(x, y, marker = 'o', ls = '--') #실제 값의 위치가 마커로 찍힘.
plt.show()

#추천하는 가장 좋은 차트는 선 그래프다. 선 그래프와 막대 그래프로 표현하는 게 가장 좋은 것 같다는 게 강사님의 의견.

# %%
#f라인 두께 linewith => lw

x = [1,2,3]
y = [4,5,6]

plt.plot(x,y, lw = '5', color='m') 
plt.show()

# %% [markdown]
# Line color
#
# |Character |Color| Character| Color|
# |---|---|---|---|
# |‘ b ’| Blue |‘ m ‘| Magenta|
# |‘ g ’| Green |‘ y ‘| yellow|
# |‘ r ‘| Red |‘ k ‘| Black|
# |‘ c ‘| cyan |‘ w ‘| white|

# %%
#색깔 바꾸기 color, 혹은 c

plt.plot(x,y, lw = '5', color='m') 
plt.show()

plt.plot(x,y, lw = '5', c='y') 
plt.show()

# %% [markdown]
# Style option
#
# |스타일옵션종류| 설명| 약자|
# |---|---|---|
# |color| 선 색깔| c|
# | linewidth| 선 굵기| lw|
# | linestyle| 선 스타일| ls|
# | marker| 마커 종류| |
# | markersize| 마커 크기| ms|
# | markeredgecolor| 마커 선 색깔| mec|
# | markeredgewidth| 마커 선 굵기| mew|
# | markerfacecolor| 마커 내부 색깔| mfc|

# %%
#마커 종류와 옵션 합치면 5가지나 있네욤.
#마커 관련된 거 제외하면 3개 남네 ㅋㅋ
#이까지는 전혀 어렵지 않고~

# %% [markdown]
# #### Matplotlib 연습 01
#
# ```
# x = np.arange(7)
# y = [1,4,5,8,9,5,3]
# ```
# 꺾은 선 그래프
#
# A

# %%
## 선 그래프 그리기 -> 점선, 점모양 마커는, 마커엣지색은 그린, 마커엣지두께는 1, 마커컬러 그린, 마커사이즈는 5

#x값이 ndarray로 쭈루룩 만들어지고, y값은 쉼표로 쭉 만들어져있음.

x = np.arange(7)
y = [1,4,5,8,9,5,3]

plt.plot(x, y, ls = '--', marker = 'o', mec = 'g',mew = '1', mfc = 'g', ms = '5' )
plt.show()

# %% [markdown]
# #### 차트 옵션
#
# |plot| 옵션 정의|
# |---|---|
# |xlim, ylim| x 축 범위, y축 범위|
# |grid| 격자눈금|
# |legend| 범례|
# |xlabel, ylabel| x축 타이틀, y축 타이틀|
# |title| 그래프 제목|
# |xticks, yticks |x축 눈금 조정, y축 눈금 조정|

# %% [markdown]
# #### 그림 범위 지정
#
# - 플롯 그림을 보면 몇몇 점들은 그림의 범위 경계선에 있어서 잘 보이지 않는 경우
# - 그림의 범위를 수동으로 지정하려면 xlim 명령과 ylim 명령을 사용
# - 그림의 범위가 되는 x축, y축의 최소값과 최대값을 지정

# %%
plt.xlim(-2,8) #x축 범위 최대와 최소를 지정해준 것.
plt.ylim(-5,10) #y축 최대 범위와 최소 범위를 지정해준 것.

plt.plot(x, y, ls = '--', marker = 'o', mec = 'g',mew = '1', mfc = 'g', ms = '5' )
plt.show()

# %% [markdown]
# #### 틱(tick)
#
# 플롯이나 차트에서 축상의 위치 표시 지점
#
# - 틱 라벨(tick label) : 틱에 써진 숫자 혹은 글자
# - 틱의 위치나 틱 라벨은 Matplotlib가 자동으로 정해주지만  수동으로 설정시 xticks , yticks 명령을 사용

# %%
#틱은 수동으로 지정해주지 않으면 맷플로립에서 자동으로 지정해줌.  
#궁금한 점 맷플로립에서 3차원 가능?

plt.xticks( [0,3,6] ) #여기 안에 
plt.yticks( [1,5,9] )

plt.grid() #격자무늬 생성됨. 격자는 틱에 따라서 조절이 된다! 
plt.plot(x, y, ls = '--', marker = 'o', mec = 'g',mew = '1', mfc = 'g', ms = '5' )
plt.show()

# %% [markdown]
# #### 여러 개 플롯

# %%
#선 2개 이상 그릴 때!

#x값은 동일하게 하고 y값만 다르게 지정해서 넣어볼게

y1 = [1,2,3,4]
y2 = [2,4,6,8]
y3 = [3,6,9,12]

plt.plot(y1)
plt.plot(y2)
plt.plot(y3)
plt.show()

#이렇게 하면 그래프 3개가 알아서 나옴. 
#plt.show()를 만약 중간에 넣으면?

# %%
#plt.show()를 만약 중간에 넣으면?
y1 = [1,2,3,4]
y2 = [2,4,6,8]
y3 = [3,6,9,12]

plt.plot(y1)
plt.plot(y2)
plt.show()
plt.plot(y3)

#이렇게 하면 2개로 잘라져서 나옴.

# %% [markdown]
# #### 범례

# %%
#범례 : 설명 다는 거.
#어떤 게 y1 y2 y3인지 모르잖아!
#label을 달아놓으면 됨.

y1 = [1,2,3,4]
y2 = [2,4,6,8]
y3 = [3,6,9,12]

plt.plot(y1, label = 'y1')
plt.plot(y2, label = 'y2')
plt.plot(y3, label = 'y3')
plt.legend() #legend 해주면 빈 여백에 자동으로 알아서 나타난다.
plt.show

#이 정도면 선으로 표현할 수 있는 건 다 표현할 수 있다.
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# #### 차트 한글

# %%
#한글이 작동되게 하는 법. 우리는 한글로 많이 쓸 거니까~

# Windows에선 이렇게 하면 됨.!
from matplotlib import font_manager, rc

font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

# %%
from matplotlib import rc
rc('font', family='Malgun Gothic')

# %% [markdown]
#  코렙에서 한글 사용

# %%
#코랩에선 좀 복잡한데!

# !apt -qq -y install fonts-nanum     #apt는 리눅스에서 다운받는 패키지임. 이거는 한번 실행해주고 나서 다시 시작해야함 ㅠㅠ
                                    #설치가 쭉 되고 나면 잘 설치가 됐다고 나오고, 다시 실행시키자. '런타임'에서 '다시 시작'!! 이러면 초기화가 되고 다시 뜬다!
                                    #'다시 시작'하고 나면, 구글드라이브 연동은 이전에 해놨으면 이미 연결되어있음. 근데 import는 다시 해줘야함!
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
 
fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=10)
fm._rebuild()
 
# 그래프에 retina display 적용
# %config InlineBackend.figure_format = 'retina'
 
# Colab 의 한글 폰트 설정
plt.rc('font', family='NanumBarunGothic')
# Out:
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 39 not upgraded.
# Need to get 9,604 kB of archives.
# After this operation, 29.5 MB of additional disk space will be used.
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 160772 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20170925-1_all.deb ...
# Unpacking fonts-nanum (20170925-1) ...
# Setting up fonts-nanum (20170925-1) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...

# %% [markdown]
# #### Matplotlib 연습 02-1
#
# 공공데이터 : 전국사망교통사고 2017을 시각화

# %%
# 요일별 사망교통사고 시각화
import pandas as pd

df = pd.read_csv(drive_path + 'Traffic_Accident_2017.csv', encoding='euc-kr') #그냥 보기 너무 힘들지! 이때 전치행렬 쓰면 돼!
df.head().T

#UTMK가 뭐지..? 평면지도로 보면 이렇고, 구모양 지도는 위도 경도로 봄. 지도 시스템이 다름.
# Out:
#                         0            1            2            3            4
# 발생년                  2017         2017         2017         2017         2017
# 발생년월일시         2017010101   2017010102   2017010102   2017010102   2017010104
# 발생분                    15           28           43           22           37
# 주야                     야간           야간           야간           야간           야간
# 요일                      일            일            일            일            일
# 사망자수                    1            1            1            1            1
# 사상자수                    2            1            2            1            1
# 중상자수                    1            0            0            0            0
# 경상자수                    0            0            1            0            0
# 부상신고자수                  0            0            0            0            0
# 발생지시도                  전남           서울           충남           충남           서울
# ...

# %%
# 요일별 사고 건수 count

df['요일']  #인덱스로 '요일 가져옴'

#이걸 .loc으로는 왜 안될까? 인덱스 명이라 안되나? .loc은 인덱스 이름으로 쭉하는 게 아니라? 아아 잠깐만. 이거 원래 '요일'이 열에 있던 거잖아? 지금 내가 보고 있는 표는 전치행렬 된 거고. 
#원본값은 그대로잖아. 
df.loc[:,'요일'] #이렇게 하면 같은 값이 나오네.

df['요일'].value_counts() #와우 화요일이 제일 많네.
# Out:
# 화    608
# 월    603
# 금    603
# 토    596
# 목    586
# 수    565
# 일    504
# Name: 요일, dtype: int64

# %%
#이걸 시각화 시켜본다면?

y = df.loc[:,'요일'].value_counts()

plt.plot(y)

# %%
#이걸 월화수목금토일로 바꾸고 싶다면??

df.loc[:,'요일'].value_counts()

y =  y[ ['월','화','수','목','금','토','일'] ]

plt.ylim(400, 700) #간격을 조절해서 만들면 됨.

plt.plot(y)

plt.show()

#해보고 느껴지는 게, 여러 개를 비교하고 싶다 그러면 막대가 편하고, 시간에 따른 변이를 보고 싶다면 선 그래프가 편하고. 뭐 그정도임.

# %%
###막대 그래프 소개!

#이거 틱으로 어떻게 조절할까??

x = range(7)
plt.xticks(x, ['월','화','수','목','금','토','일'] ) # x, [] 이렇게 해주면 x에 매칭이 알아서 된다. 
plt.yticks( [450,500,550,600,650] )
plt.ylim(450,650)
plt.bar(x,y) #얘는 x값 y값 둘 다 지정해줘야하네.

#그래프 설명 부분. 
plt.xlabel('요일')
plt.ylabel('사고건수')
plt.title('요일별 교통사고건수')

#png 파일로 저장하기도 가능~
plt.show()

# %% [markdown]
# #### Matplotlib 연습 02-2
#
# 공공데이터 : 차 vs 차 교통사고 다발 발생지 시도 시각화

# %%
#공공데이터 : 차 vs 차 교통사고 다발 발생지 시도 시각화 2회차
df = pd.read_csv(drive_path + 'Traffic_Accident_2017.csv', encoding='euc-kr')

#차대차, 발생지시도 
df[df[ '사고유형_대분류' ] == '차대차']['발생지시도'].value_counts()
# Out:
# 경기    330
# 충남    163
# 경북    156
# 경남    146
# 전남    134
# 전북    133
# 서울    112
# 충북     95
# 강원     80
# 대구     67
# 부산     53
# 광주     42
# 인천     41
# 제주     27
# 대전     27
# 울산     26
# 세종     10
# Name: 발생지시도, dtype: int64

# %%
#공공데이터 : 차 vs 차 교통사고 다발 발생지 시도 시각화 2회차
df = pd.read_csv(drive_path + 'Traffic_Accident_2017.csv', encoding='euc-kr') #그냥 보기 너무 힘들지! 이때 전치행렬 쓰면 돼!
df.head().T

#내가 가져올 정보는 '차대차', '발생지시도'
#차대차 사고가 어디서 많이 일어나는가?

#팬시인덱싱 하면 되잖아?
acc = df[ ['발생지시도','사고유형_대분류'] ] #열기준이니까 그냥 불러와~
#불린으로 사고유형에서 차대차를 뽑아올 건데
car_acc = acc[acc['사고유형_대분류'] == '차대차']
car_acc['발생지시도']  #어짜피 열기준이라 그냥 뽑아오면 돼
car_acc['발생지시도'].value_counts()
# Out:
# 경기    330
# 충남    163
# 경북    156
# 경남    146
# 전남    134
# 전북    133
# 서울    112
# 충북     95
# 강원     80
# 대구     67
# 부산     53
# 광주     42
# 인천     41
# 제주     27
# 대전     27
# 울산     26
# 세종     10
# Name: 발생지시도, dtype: int64

# %%
#내가 풀다 막힌 것
df.head().T

#차 vs 차,어디서 많이 나는지

car_car = df[df.loc[:,'사고유형_대분류'] == '차대차']
acc_map = df.loc[:,'발생지시도'].value_counts()
#print(car_car)
#print(acc_map)

car_acc_map = df.loc[:,['사고유형_대분류','발생지시도']].value_counts()
car_acc_map


df.loc[:,'사고유형_대분류'] == '차대차'
car_car =  df['사고유형_대분류'] == '차대차'
car
# Out:
# 0        True
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 4060     True
# 4061    False
# 4062    False
# 4063     True
# 4064    False
# Name: 사고유형_대분류, Length: 4065, dtype: bool

# %%
#강사님이 풀어준 것
#복습 필수

t = df[ ['발생지시도', '사고유형_대분류'] ] # 리스트로 쭉 넣으면 한번에 가져올 수가 있다.   #이 코드와 바로 아래 코드는 동일하다.
#df.loc[:,['발생지시도','사고유형_대분류']] # 행에서 인덱스를 가져오는 거니까.
t = t[t[ '사고유형_대분류' ] == '차대차']
t['발생지시도'].value_counts()
# Out:
#      발생지시도 사고유형_대분류
# 0       전남      차대차
# 1       서울     차대사람
# 2       충남      차대차
# 3       충남     차량단독
# 4       서울     차대사람
# ...    ...      ...
# 4060    경남      차대차
# 4061    부산     차량단독
# 4062    강원     차량단독
# 4063    경기      차대차
# 4064    대전     차대사람
#
# [4065 rows x 2 columns]

# %%
#bar 그래프로 만들어보기
#강사님이 풀어준 것
#복습 필수

t = df[ ['발생지시도', '사고유형_대분류'] ] # 리스트로 쭉 넣으면 한번에 가져올 수가 있다.   #이 코드와 바로 아래 코드는 동일하다.
#df.loc[:,['발생지시도','사고유형_대분류']] # 행에서 인덱스를 가져오는 거니까.
t = t[t[ '사고유형_대분류' ] == '차대차']
t = t['발생지시도'].value_counts()

x = t.index
y = t.values

plt.bar(x,y)
plt.show()

# %%
df.head().T
# Out:
#                         0            1            2            3            4
# 발생년                  2017         2017         2017         2017         2017
# 발생년월일시         2017010101   2017010102   2017010102   2017010102   2017010104
# 발생분                    15           28           43           22           37
# 주야                     야간           야간           야간           야간           야간
# 요일                      일            일            일            일            일
# 사망자수                    1            1            1            1            1
# 사상자수                    2            1            2            1            1
# 중상자수                    1            0            0            0            0
# 경상자수                    0            0            1            0            0
# 부상신고자수                  0            0            0            0            0
# 발생지시도                  전남           서울           충남           충남           서울
# ...

# %% [markdown]
# #### 카테고리 (범주형)

# %%
ages = [0, 2, 10, 21, 23, 37, 31, 61, 20, 41, 32, 100]
bins = [0, 15, 25, 35, 60, 99]
labels = ["미성년자", "청년", "중년", "장년", "노년"]

# %% [markdown]
# #### Matplotlib 연습 02-2
#
# 교통사고 다발 시간대 시각화
#
# > 0-2, 3-5, 6-8, 9-11, 12-14, 15-17, 18-20, 21-23시 8개의 구간으로 나누어서 진행

# %%
##교통사고 다발 시간대 시각화 3회차
bins = [-1,2,5,8,11,14,17,20,23]
labels = ['0-2', '3-5', '6-8', '9-11', '12-14', '15-17', '18-20', '21-23']

#시간대 추출
time = df['발생년월일시'] % 100
time
time_cut = pd.cut(time, bins, labels=labels)
time_cut.value_counts()
# Out:
# 18-20    692
# 15-17    550
# 9-11     526
# 21-23    494
# 12-14    472
# 6-8      466
# 3-5      444
# 0-2      421
# Name: 발생년월일시, dtype: int64

# %%
#교통사고 다발 시간대 시각화 2회차

bins = [-1,2,5,8,11,14,17,20,23]
labels = ['0-2', '3-5', '6-8', '9-11', '12-14', '15-17', '18-20', '21-23']

df.head().T
#시간 추출해야하는데, 여기서 아이디어는 이거 발생년월일시 저기다가 %100 하면 시 나오잖아!

time = df['발생년월일시'] % 100
time

time_cuts = pd.cut(time, bins, labels=labels)
time_cuts

time_cuts.value_counts()
# Out:
# 18-20    692
# 15-17    550
# 9-11     526
# 21-23    494
# 12-14    472
# 6-8      466
# 3-5      444
# 0-2      421
# Name: 발생년월일시, dtype: int64

# %%
##시간부터 추출 
##복습 필수!! 열심히!!

#힌트 : 파이썬 기초할 때, 456에서 백의 자리 빼고 십의 자리 가져왔던 거
#뒤에서 두자리만 갖고 오고 싶은데.. 어떻게 갖고 오지?
#오오 %100 써서 뒤에 2자리 갖고 오면 되네??

df.head().T

t = df[ '발생년월일시']
time_df = t % 100
time_df

#time = time_df.value_counts() #이렇게 하면 시간대별로 나온다. 이건 그룹화하고 싶어도 못하고, 범주화 시켜야함
#print(time) 
#여기서 밸류카운트를 먼저해서 컷을 먼저 해버리면 값을 기준으로 해야하는데 그게 안되니까, 밸류카운팅을 해주면 안되는 거였음.

bins = [-1, 2, 5, 8, 11, 14, 19, 20, 23]
labels = ["0-2", "3-5", "6-8", "9-11", "12-14", "15-17", "18-20", "21-23"]

time_cuts = pd.cut( time_df, bins, labels=labels ) #카테고리 만들기

time_cuts.value_counts()
# Out:
# 15-17    1051
# 9-11      526
# 21-23     494
# 12-14     472
# 6-8       466
# 3-5       444
# 0-2       421
# 18-20     191
# Name: 발생년월일시, dtype: int64

# %%
times = (df['발생년월일시'] % 100)
bins = [-1, 2, 5, 8, 11, 14, 17, 20, 23]
labels = ["0-2", "3-5", "6-8", "9-11", "12-14", "15-17", "18-20", "21-23"]

times_cuts = pd.cut(times, bins, labels=labels)
times_cuts = times_cuts.value_counts()
times_cuts
# Out:
# 18-20    692
# 15-17    550
# 9-11     526
# 21-23    494
# 12-14    472
# 6-8      466
# 3-5      444
# 0-2      421
# Name: 발생년월일시, dtype: int64

# %%
#강사님이 풀어준 것
bins = [-1, 2, 5, 8, 11, 14, 17, 20, 24]
labels = ['0-2', '3-5', '6-8', '9-11', '12-14', '15-17', '18-20', '21-23']
time_cuts = pd.cut(time_df.values, bins, labels=labels)
rs = time_cuts.value_counts()

#강사님이 바차트 만든 것
x = rs.index
y = rs.values
plt.ylim(300, 700)
plt.bar(x, y)
plt.show()

# %%
#파이차트 직접 그려보자!

plt.figure( figsize=(5,5) ) #길이 지정. 도화지라고 하기도 함 
plt.pie(rs, labels=labels)  #이렇게만 하면 수치가 없음.  
plt.pie(rs, labels=labels, autopct='%1.1f%%')  #수치 넣기

#표를 여러개 그리는 방법

plt.show()

# %%
#표를 여러개 그리는 방법

#위치를 지정해주고 여러개 출력하기

plt.figure( figsize=(8,8) )

plt.subplot(2 ,2 ,1)    #2행 2열로 만들겠다는 이야기. 인덱스 1번
plt.pie(rs, labels=labels, autopct='%1.1f%%')

plt.subplot(2 ,2 ,2)    #2행 2열로 인덱스 2번
plt.pie(rs, labels=labels, autopct='%1.1f%%')

plt.subplot(2 ,2 ,4)    #2행 2열로 인덱스 4번
plt.pie(rs, labels=labels, autopct='%1.1f%%')

plt.show()
# 1번 2번
# 3번 4번 아까 3번 비었으니까 4번 있음!

# %%
# 파이차트의 옵션들!
labels = ('A', 'B', 'C') 
xs = [50, 30, 40] 

patches, texts, autotexts = plt.pie(
    labels=labels, 
    labeldistance=1.1,   # label과 파이의 간격, 1일 경우 딱 붙음. 
    x = xs,              # 값
    explode=(0.1, 0.1, 0), # 파이조각 돌출 크기 (0 이면 돌출되지 않음)
    startangle=90,       # 그려지는 파이 조각 시작위치. 90은 12시 방향 
    shadow=False,        # 파이차트 그림자 효과 유무
    counterclock=False,  # 파이차트가 그려질 방향 (시계방향, 반시계 방향) 
    autopct='%1.1f%%',   # 파이조각 위에 표시될 글자 형태 (파이조각 전체대비 백분율)
    pctdistance=0.7,     # 백분률 표시 위치 (radius 기준으로 위치 선정)
    colors=['grey', 'red', 'blue'],  # 각 파이조각 컬러
)

# %% [markdown]
# #### Matplotlib 연습 02-3
#
# 교통사고 지역 지도 시각화

# %%
#데이터 불러오기~

df = pd.read_csv(drive_path + 'Traffic_Accident_2017.csv', encoding='euc-kr') #그냥 보기 너무 힘들지! 이때 전치행렬 쓰면 돼!
df.head().T
# Out:
#                         0            1            2            3            4
# 발생년                  2017         2017         2017         2017         2017
# 발생년월일시         2017010101   2017010102   2017010102   2017010102   2017010104
# 발생분                    15           28           43           22           37
# 주야                     야간           야간           야간           야간           야간
# 요일                      일            일            일            일            일
# 사망자수                    1            1            1            1            1
# 사상자수                    2            1            2            1            1
# 중상자수                    1            0            0            0            0
# 경상자수                    0            0            1            0            0
# 부상신고자수                  0            0            0            0            0
# 발생지시도                  전남           서울           충남           충남           서울
# ...

# %% [markdown]
# folium 지도라이브러리 설치
#
# https://python-visualization.github.io/folium/

# %%
# !pip install folium #코랩엔 이미 설치되어있음!

# %% [markdown]
# 지도 만들기

# %%
import folium
seoul_map = folium.Map( location=[37.55, 126.98], zoom_start=12, width='100%', height='100%' ) #로케이션에 리스트로 위도경도 넣어주면 됨. 줌은 줌 몇에서 시작할 거냐는 거. 넓이와 높이는 나오는 위치 조절.
seoul_map

#웹사이트에선 구글이나 다음 카카오맵 이런 거 쓰셈~ 이건 파이썬용 지도니까
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...

# %%
#지도에 스타일 넣기

seoul_map = folium.Map( location=[37.55, 126.98], zoom_start=12, tiles='Stamen Toner' ) #tiles는 스타일임. 토너로 넣으면 흑백도 나오고.. 뭐 지도에서 제일 중요한 건 마커니까~~
seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...

# %% [markdown]
# 지도 스타일 적용

# %% [markdown]
# 지도에 마커 표시

# %%
df[ ['경도','위도'] ].head()    #df[ ['경도','위도] ] 경도 위도를 리스트로 넣어주고~
# Out:
#            경도         위도
# 0  126.768634  35.294464
# 1  127.133107  37.498741
# 2  126.566631  36.580069
# 3  127.069759  36.778505
# 4  126.898094  37.472946

# %%
#발생지시도가  서울인 녀석들만 가져오면 되지!
#여기도 복습 필수일듯 ㅠ 마커 쓰고 그런 것보다 데이터에 접근하는 거!!!!

s = df[ df['발생지시도'] == '서울' ]
s[ ['발생년월일시','위도','경도'] ]

#위에랑 아래랑 같다.
s = df[ df['발생지시도'] == '서울' ][ ['발생년월일시','위도','경도'] ]
s.head()
# Out:
#         발생년월일시         위도          경도
# 1   2017010102  37.498741  127.133107
# 4   2017010104  37.472946  126.898094
# 12  2017010204  37.619097  126.915444
# 16  2017010208  37.487492  126.897739
# 20  2017010217  37.443959  126.903492

# %%
#발생지시도가  서울인 녀석들만 가져오면 되지! 데이터 접근하기 2회차
# 발생년월일시 ,위도, 경도 불러오기
df.head().T

s = df[df['발생지시도'] == '서울'] #발생지시도가 서울인 것만 우선적으로 불러오고 , 그 다음에 발생년월일시하고 위도, 경도만 한번 더 빼오기
s[ ['발생년월일시','위도','경도'] ].head()  

#0624 오늘 복습하면서 느낀 건, 판다스는 열 중심이라는 것. 열 중심이니까, 그냥 df['~~~']로 하나 접근하거나, df[ ['a','b','c'] ] 이렇게 여러개 열에 리스트로 한번에 접근하거나
# Out:
#         발생년월일시         위도          경도
# 1   2017010102  37.498741  127.133107
# 4   2017010104  37.472946  126.898094
# 12  2017010204  37.619097  126.915444
# 16  2017010208  37.487492  126.897739
# 20  2017010217  37.443959  126.903492

# %% [markdown]
# 원형 마커

# %%
folium.Marker( [37.55, 126.98], popup = 'hello' ).add_to(seoul_map)
seoul_map

# %%
#테스트 해보는 거임
a = [1,2,3]
b = ['일','이','삼']

#for a,b in a, b:   #이렇게 하면 안오고, zip으로 묶어줘야함.
  #print(a,b)

for a,b in zip(a, b):
  print(a,b)

# %%
#for 문 돌리면서 가져오게 될 건데, 대체 뭔 소리일까?!?!!? 뭐 복습하다보면 알게 되겠지!!!!

for time, lat, lng in zip(s['발생년월일시'].astype(str), s['위도'], s['경도']):
  folium.Marker([lat, lng], popup=time).add_to(seoul_map)

seoul_map

#이게 쭉 돌아가면서 자동으로 지도에 마커를 찍게 될 거임
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...

# %% [markdown]
# 지도를 HTML 파일로 저장

# %%
seoul_map.save(drive_path + 'seoul_map.html')

#보통 웹에선 다음 맵이나 카카오맵같은 거 씀.

# %% [markdown]
# ## Matplotlib 추가사항

# %%
fig, axes = plt.subplots(2, 3) #개별 도표에 대한 정보가 axes에 들어옴. 이렇게 그리는 방법도 있다!

# %%
fig = plt.figure() #fig는 우리가 쓰는 도화지에 대한 정보가 온다. 이거나 이거 바로 위에 셀에 있는 거를 많이 쓴다.

ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)

# %%
# ax 1이라고 했던 곳에 그림 그려보겠음!
import numpy as np

ax1.hist(np.random.randn(200), bins=20, color='k')
ax2.scatter(np.arange(30), np.arange(30) + 3*np.random.randn(30) ) #랜덤하게 흩어놓기 위해서 노이즈를 좀 섞을 거임. 산점도?
ax3.plot(np.arange(10), np.random.randn(10)) #이건 우리가 배웠던 것. 

fig
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# #### subplot 주변의 공간 고정

# %% [markdown]
# ### subplot 주석달기 및 그리는 방법

# %%
fig, axes = plt.subplots(2, 1)

data = pd.Series(np.random.randn(16)) #랜덤으로 가상의 데이터 16개 만든 거임.

data.plot(king='bar', ax=axes[0], alpha=0.5)   # plot도 여러 종류로 그릴 수가 있다. alpha 는 투명도에 대한 이야기.
data.plot(king='barh', ax=axes[1], alpha=0.7)  # h하면 옆으로 누워있는 바가 나옴.

# %% [markdown]
# ## Pandas 내장 그래프 도구
#
# - Pandas는 Matplotlib 라이브러리의 기능 일부를 내장
# - 별도의 임포트를 하지 않고 간단한 그래프 가능

# %% [markdown]
# Pandas 내장 plot() 메소드 그래프 종류
#
# |kind 옵션| 설명 |
# |---|---|
# |line| 선 그래프|
# |bar| 수직 막대 그래프|
# |barh| 수평 막대 그래프|
# |his| 히스토그램|
# |box| 박스 플롯|
# |kde| 커널 밀도 그래프|
# |area| 면적 그래프|
# |pie| 파이 그래프|
# |scatter| 산점도 그래프|
# |hexbin| 고밀도 산점도 그래프|

# %% [markdown]
# ### 선 그래프
#  DataFrame 객체.plot()
#
#  - 시간의 흐름에 따른 변화 추이를 보기 위해 사용

# %%
import pandas as pd

#  '남북한발전전력량.xlsx'

df = pd.read_excel(drive_path + '남북한발전전력량.xlsx')

df_ns = df.iloc[ [0,5],2: ] #연속된 구간이 아닐땐 그냥 원하는 위치값 넣어주면 돼.
                          #1990부터 가져오려면 2부터 가져와야할듯
df_ns.index = ['South','North']
df_ns
# Out:
#        1990  1991  1992  1993  1994  1995  ...  2011  2012  2013  2014  2015  2016
# South  1077  1186  1310  1444  1650  1847  ...  4969  5096  5171  5220  5281  5404
# North   277   263   247   221   231   230  ...   211   215   221   216   190   239
#
# [2 rows x 27 columns]

# %%
df_ns.plot() #이렇게만 뽑아놓으면 축이 다름. 
#방향을 바꿔준 다음에 그림을 그려줘야함.
df_ns.T.plot() #이렇게 해야 그림이 좀 잘 그려짐

# %% [markdown]
# ### 막대 그래프
#
# DataFrame 객체.plot(kind='bar')
#
# - 선 그래프와 비슷하게 변화 추이를 보기 위해 사용

# %%
df_ns.T.plot(kind = 'bar')

# %% [markdown]
# ### 히스토그램
#
# DataFrame 객체.plot(kind='hist')
#
# - 연속된 자료의 분포를 보기 위해 사용

# %%
df_ns.T.plot(kind='hist')  #분포는 보통 종모양으로 되어있으면 좋다고 함.

# %% [markdown]
# ### 산점도
#
# DataFrame 객체.plot(kind='scatter')
#
# - 두 변수의 관계를 보기 위해 사용

# %%
import pandas as pd

df = pd.read_csv(drive_path + 'auto-mpg.csv',header=None) #헤더 없이 출력했더니 한 줄 날아갔음. 열 이름이 아니고 데이터인데 열 이름으로 들어가있었다 ㅋㅋ 헤더 None을 지정해줘야함
df

#열 이름 지정
df.columns = ['mpg','cylinders','displacement','horsepower','weight',
              'acceleration','model year','origin','name']

#우리가 볼 건 연비! 연비가 ~~와 관련이 있느냐 없느냐! 이것만 보면 됨. 그리고 파일 처음 가져오면 .info() 해서 결측치가 있는지 없는지, object파일 있는지 없는지 봐야함.
df.info() #오브젝트 파일은 수치로 바꿔야 쓸 수 있음. 데이터 분석할 때는 상관 없는데 머신러닝 넘어가면 학습을 못함 그거로.

#  'auto-mpg.csv'

#~~가 연비와 좋을까 안좋을까! 이렇게 2변수 간의 상관관계를 보는 게 산점도에 대한 이야기. 둘의 관계를 보고 싶을 때는 산점도. scatter를 쓰면 돼.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    float64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
#~~가 연비와 좋을까 안좋을까! 이렇게 2변수 간의 상관관계를 보는 게 산점도에 대한 이야기. 둘의 관계를 보고 싶을 때는 산점도. scatter를 쓰면 돼.
df.plot(kind='scatter', x='model year', y='mpg') #얘는 연도별로 보니까 이렇게 출력됨.

# %%
#차 모델로 봤을 때 연비가 가장 좋은 차는 뭘까?
df
# mpg가 45이상인 차들 찾기
mpg_45 = df[df['mpg'] > 45]
mpg_45
#mpg_model = df[ ['mpg','name'] ]

#어떻게 sort하는지 궁금한데?
# Out:
#       mpg  cylinders  displacement  ... model year  origin       name
# 322  46.6          4          86.0  ...         80       3  mazda glc
#
# [1 rows x 9 columns]

# %%
#차 모델로 봤을 때 연비가 가장 좋은 차는 뭘까?
#강사님이 풀어준 것

df[ df['mpg'] > 45 ]
# Out:
#       mpg  cylinders  displacement  ... model year  origin       name
# 322  46.6          4          86.0  ...         80       3  mazda glc
#
# [1 rows x 9 columns]

# %% [markdown]
# ### 박스 플롯
#
# DataFrame 객체.plot(kind='scatter')
#
# - 특정 변수의 데이터 분포와 분산 정도를 보기 위해 사용
# - 각 변수들의 데이터가 퍼져 있는 정도를 확인하기 위해

# %%
#열 (연비, 실린더) 선택하여 박스 플롯 그리기
df[ ['mpg','cylinders'] ].plot(kind='box') #여기서는 값이 큰 애가 훨씬 영향을 더 많이 받음. 정규화한다고 이야기하는데 뭐 그렇다.

#어느 정도 분포를 보고 싶을 때, 산점도를 이용함.

# %%
# 열(연비,실린더)을 선택하여 박스 플롯 그리기

# %% [markdown]
# ## Seaborn 시각화

# %%
#seaborn이 그렇게 편하다면서?
import seaborn as sns

df = sns.load_dataset('mpg')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
# 히스토그램

sns.displot( df['mpg'], bins=50, kde=True, color='r' )   #자료를 넣어줘야하니까 데이터프레임의 mpg를 쓰겠다고 하면 mpg에 대해서만 만들어짐
#kde는 커널밀도 함수를 통한 곡선을 그려줌.
#색상은 컬러로 바꾸면 됨.
plt.show()

# %%
# Hex
#헥사로 했기 때문에 6각형이 나오는 거임.

#sns.jointplot(kind = 'hex', data=df)    #이러면 y값이 없다고 오류가 뜬다.
sns.jointplot(kind = 'hex', data=df, x='weight', y='mpg', color='green', ) #분명 무게와 연비의 상관관계를 다루겠다는 이야기였는데요...
                                                          #위에는 히스토그램임. 히스토그램과 산점도를 동시에 보여준다..

# %%
# kde
#만약에 hex가 아니라 kde로 바꾸면?!
sns.jointplot(kind='kde', data=df, x='weight', y='mpg', color='green')
plt.show()

# %%
# box
sns.boxplot(data=df, y='mpg')

# %%
#만약에 박스를 여러개 그려주고 싶다면?!
sns.boxplot(data=df, y='mpg', x='origin')
plt.show()

# %%
# 바이올린
sns.violinplot(data=df, y='mpg', x='origin')

# %%
#붓꽃 품종 건드리는 거..

df = sns.load_dataset('iris')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# 산점도 행렬
#산점도는 2개만 비교할 수 있음. 근데 붓꽃은 요소가 4개잖아? 4x4. 많은 요소가 있을 때 어떤 요소들이 제일 연관도가 높느냐! 이런 것을 좀 봄. 
sns.pairplot(df)

# %%
#예쁘게 그려보기

sns.pairplot(df, hue='species') #분류용으로 사용하기 좋은 녀석임. 분류용으로 산점도 자주 활용함

# %%
# heatmap

sns.heatmap(df.corr())
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)
